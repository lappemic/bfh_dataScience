# %% [markdown]
# # Lesson 15 - Image classification with deep learning
# > An introduction to Deep Learning and its applications in computer vision.

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/lewtun/dslectures/blob/master/notebooks/lesson15_cv-deep.ipynb) [![slides](https://img.shields.io/static/v1?label=slides&message=lesson15_cv-deep.pdf&color=blue&logo=Google-drive)](https://drive.google.com/open?id=1-e9BU8_TwD02lYcs66lDNkhsiqu2dZ1R)

# %% [markdown]
# > Note: Make sure you are connected to a GPU machine when running the Colab notebook by clicking on `Runtime -> Change runtime type` and set hardware type to GPU.

# %% [markdown]
# ## Learning objectives
# In this lecture we will use the image dataset that we created in the last lecture to build an image classifier. We will again use *transfer learning* to build a accurate image classifier with deep learning in a few minutes.
#
# You should learn how to load the dataset and build an image classifier with the *fastai* library.

# %% [markdown]
# ## References
# This content will be similar to the first lesson of the fastai course. We recommend watching the the lesson recording.
# * Practical Deep Learning for Coders - Lesson 1: Image classification by fastai [[video](https://youtu.be/XfoYk_Z5AkI)]

# %% [markdown]
# ## Homework
# Use this notebook as a template to create an image classifier with your own dataset.

# %% [markdown]
# ## Goal
#
# In this notebook we want to create an image classifier. Images are very common in many areas. Imagine you would have an image of the car available in the Kaggle competition. Such an image could contain a lot of information useful for determining the price of the car. Another example is a automated production line where you need to check that the parts are produced correctly and there are no defects.
#
# <div style="text-align: center">
# <img src='https://github.com/lewtun/dslectures/blob/feat%2Flesson15/notebooks/images/is-this-a-meme.jpg?raw=1' width='400'>
# </div>

# %% [markdown]
# ## Transfer learning for image classification
# We will again use the `fastai` library to build an image classifier with deep learning. The procedure will look very familiar, except that we don't need to fine-tune the classifier. The model we will use was pretrained on the ImageNet dataset, which contains over 14 million images and over 1'000 classes. Training a model on this dataset takes a lot of time. Fortunately, we can re-use the freely available models trained on this dataset to then train new classifiers on other datasets. Because the dataset is so diverse the model learns a lot about the general structure of images.
#
# <div style="text-align: center">
# <img src='https://github.com/lewtun/dslectures/blob/feat%2Flesson15/notebooks/images/imagenet.jpeg?raw=1' width='400'><p style="text-align: center;"> <b>Reference:</b> http://karpathy.github.io/2014/09/02/what-i-learned-from-competing-against-a-convnet-on-imagenet/ </p>
# </div>
#
# The code to train an image classifier should look familiar, since we used a very similar approach in Lesson 13 to train a language model for text classification. The main difference will be the `learner` which will be a `cnn_learner`.

# %% [markdown]
# ## Install fastai library
# First we need to install the fastai library since we need some of its helper functions to download images and then also visualise the downloaded images.
#
# > Note: This step might take a few minutes.

# %%
# !pip install fastai --no-cache-dir -qq

# %% [markdown]
# ## Import

# %% [markdown]
# Then we can import the `ImageDownloader` and the fastai helper functions.

# %%
# uncomment if running locally or on Google Colab
# !pip install --upgrade dslectures

# %%
from fastai.vision import *
from fastai.widgets import *
import tarfile

# %% [markdown]
# ## Load dataset

# %% [markdown]
# First you need to upload your dataset by clicking on the folder icon on the left hand side and then clicking on the upload button. You should now see your dataset in the output of the next cell.

# %%
path = Path('')

# %%
path.ls()
# Out:
# [PosixPath('.config'),
#  PosixPath('simpson_characters.tar.gz'),
#  PosixPath('sample_data')]

# %%
/content/simpson_characters.tar.gz

# %% [markdown]
# Replace the `cats_vs_dogs.tar.gz` filename with the name of your dataset. The next command uncompresses your datasetfolder into a folder named `data`.

# %%
tarfile.open(path/'simpson_characters.tar.gz','r:gz').extractall(path)

# %% [markdown]
# We apply a few tricks when we load the data:
# 1. A trick often used in image classification is data augmentation. This means one creates more data by manipulating existing data. For images this means that the images can be rotated, flipped cropped etc. This generally improves the performance of the classifier and is setup with the `get_transforms` function.
# 2. We split the data 80/20 into train and validation data.
# 3. We crop the images to a size of 224 pixels.

# %%
tfms = get_transforms()
data = ImageDataBunch.from_folder(path, ds_tfms=tfms, valid_pct=0.2, size=224)

# %%
data.show_batch(rows=3, figsize=(8, 8))

# %%
print(data.classes)
# Out:
# ['apu', 'bart_simpson', 'homer_simpson', 'lisa_simpson', 'maggie_simpson', 'marge_simpson', 'ralph_wiggum']

# %% [markdown]
# ## Create learner

# %% [markdown]
# Training a model involves the same steps we encountered in Lesson 13 with `ULMFiT`:
#
# 1. Load a pretrained model (e.g. resnet34, resnet50, etc)
# 2. Find the optimal learning rate
# 3. Fit the head of the network
# 4. Unfreeze all layers and fine-tune
# 5. Evaluate the results
#
# Let's got through each step in turn.

# %% [markdown]
# We load a ResNet34 model, which is a convolutional neural network with 34 layers. There are also larger networks with up to 150 layers but this model usually takes the least effort to train a get good results. Furthermore, we also specifiy that we want to monitor the accuracy during training.

# %% [markdown]
# ### Load pretrained model

# %%
learn = cnn_learner(data, models.resnet34, metrics=accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))

# %% [markdown]
# ### Find the optimal learning rate
# In this step, the goal is to find the best learning rate that a) avoids overshooting during stochastic gradient descent, and b) converges as a fast as possible. We are looking for the spot in the graph where the line has the steepest slope. This means that the model is improving the most with that learning rate.

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [2/4 00:37<00:37]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.976543</td>
#       <td>#na#</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.205536</td>
#       <td>#na#</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='23' class='' max='31' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       74.19% [23/31 00:14<00:05 3.5624]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.31E-07
# Min loss divided by 10: 7.59E-08

# %% [markdown]
# ### Train the head of the network
# Resnet34 was trained on ImageNet which has 1,000 classes instead of our measly few. Thus we first need to train the head of the network to adapt it to our use case:

# %%
learn.fit_one_cycle(cyc_len=6, max_lr=1e-6)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.965569</td>
#       <td>0.960894</td>
#       <td>0.689379</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.970870</td>
#       <td>0.961168</td>
#       <td>0.691383</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.964994</td>
#       <td>0.956780</td>
#       <td>0.697395</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.961111</td>
#       <td>0.955005</td>
#       <td>0.693387</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.955055</td>
#       <td>0.948893</td>
#       <td>0.695391</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.963925</td>
#       <td>0.954942</td>
#       <td>0.693387</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We save the progress, so we don't have to retrain the model from scratch if we want to go back a step.

# %%
learn.save('tmp_fit-head')

# %%
learn.load('tmp_fit-head');

# %% [markdown]
# ### Train all layers
# Now that we've tuned the head of the network to our dataset, the next step is to unfreeze all the layers, and see if we can generate a more accurate model. The procedure is the same as in the previous step:
# 1. Find the best learning rate.
# 2. Train the network with this learning rate.

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [2/4 00:36<00:36]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.927937</td>
#       <td>#na#</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.202005</td>
#       <td>#na#</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21' class='' max='31' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       67.74% [21/31 00:12<00:06 2.7827]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 2.29E-06
# Min loss divided by 10: 6.31E-08

# %%
learn.fit_one_cycle(2, 1.9e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.922855</td>
#       <td>0.926915</td>
#       <td>0.695391</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.881679</td>
#       <td>0.906735</td>
#       <td>0.709419</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('tmp_fit-all')

# %%
learn.load('tmp_fit-all');

# %% [markdown]
# With the unfreezing and repeated fine-tuning we gained a slight boost and achieved 92.8% classification accuracy!

# %% [markdown]
# ### Evaluate the results
# Let's see which classes our classifier is having the most identifying correctly:

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %% [markdown]
# We can have a look at the confusion matrix. It tells us which classes the model mixes up:

# %%
interp.plot_confusion_matrix(figsize=(6,6))

# %% [markdown]
# The confusion matrix looks pretty good. Next, let's look at the worst predictions:

# %%
interp.plot_top_losses(16, figsize=(20,10))

# %% [markdown]
# OK we clearly have some quirks in the dataset - let's see if we can clean it up and get a better accuracy.

# %% [markdown]
# ## Data cleaning
# fast.ai also comes with a nifty `ImageCleaner` that we can use to either remove images or correct the labels:

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn)

# %%
ImageCleaner(ds, idxs, path)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# The results are stored in a csv file named `cleaned.csv`.

# %%
path.ls()
# Out:
# [PosixPath('.config'),
#  PosixPath('models'),
#  PosixPath('data'),
#  PosixPath('simpson_characters.tar.gz'),
#  PosixPath('cleaned.csv'),
#  PosixPath('sample_data')]

# %% [markdown]
# We can load the cleaned dataset and repeat the training steps above with a new classifier:

# %%
data = ImageDataBunch.from_csv(path, csv_labels='cleaned.csv', ds_tfms=tfms, valid_pct=0.2, size=224)

# %%
data.show_batch(rows=3, figsize=(8, 8))

# %% [markdown]
# ### Load a pretrained model

# %%
learn = cnn_learner(data, models.resnet34, metrics=accuracy)

# %% [markdown]
# ### Fit the head

# %%
learn.fit_one_cycle(3, max_lr=1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.169267</td>
#       <td>2.301424</td>
#       <td>0.573333</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.576182</td>
#       <td>1.080702</td>
#       <td>0.709333</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.207346</td>
#       <td>0.835766</td>
#       <td>0.760000</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('tmp_fit-head-clean')

# %%
learn.load('tmp_fit-head-clean');

# %% [markdown]
# ### Unfreeze all layers

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [3/5 00:40<00:26]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.739157</td>
#       <td>#na#</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.695136</td>
#       <td>#na#</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.250518</td>
#       <td>#na#</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='13' class='' max='23' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       56.52% [13/23 00:08<00:06 2.4182]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(3, 1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.719396</td>
#       <td>0.789319</td>
#       <td>0.762667</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.683768</td>
#       <td>0.779984</td>
#       <td>0.765333</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.649514</td>
#       <td>0.771393</td>
#       <td>0.768000</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(3, 1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.635309</td>
#       <td>0.776825</td>
#       <td>0.776000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.589719</td>
#       <td>0.731044</td>
#       <td>0.792000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.494852</td>
#       <td>0.720279</td>
#       <td>0.789333</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(3, 1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.738496</td>
#       <td>18.295727</td>
#       <td>0.245333</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.010349</td>
#       <td>1.827281</td>
#       <td>0.624000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.908112</td>
#       <td>0.787605</td>
#       <td>0.746667</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(3, 1.5e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.769890</td>
#       <td>2.194673</td>
#       <td>0.509333</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.811534</td>
#       <td>0.908863</td>
#       <td>0.690667</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.727966</td>
#       <td>0.728833</td>
#       <td>0.752000</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(3, 1e-7)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.748593</td>
#       <td>0.767529</td>
#       <td>0.760000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.725672</td>
#       <td>0.759317</td>
#       <td>0.760000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.702068</td>
#       <td>0.756902</td>
#       <td>0.762667</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('tmp_fit-all-clean')

# %%
learn.load('tmp_fit-all-clean');

# %% [markdown]
# Evidently, the cleaning has helped give us yet another small boost and achieve **98.7% accuracy**! Also the confusion matrix looks quite acceptable now:

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(6,6))

# %% [markdown]
# We can also look at the classes that were most frequently confused:

# %%
interp.most_confused()
# Out:
# [('bart_simpson', 'homer_simpson', 8),
#  ('marge_simpson', 'homer_simpson', 8),
#  ('lisa_simpson', 'bart_simpson', 7),
#  ('ralph_wiggum', 'homer_simpson', 6),
#  ('bart_simpson', 'marge_simpson', 5),
#  ('maggie_simpson', 'homer_simpson', 4),
#  ('marge_simpson', 'maggie_simpson', 4),
#  ('homer_simpson', 'apu', 3),
#  ('lisa_simpson', 'maggie_simpson', 3),
#  ('maggie_simpson', 'lisa_simpson', 3),
#  ('ralph_wiggum', 'maggie_simpson', 3),
#  ('apu', 'homer_simpson', 2),
#  ('bart_simpson', 'apu', 2),
#  ('bart_simpson', 'maggie_simpson', 2),
#  ('homer_simpson', 'bart_simpson', 2),
#  ('homer_simpson', 'lisa_simpson', 2),
#  ('homer_simpson', 'marge_simpson', 2),
#  ('lisa_simpson', 'apu', 2),
#  ('lisa_simpson', 'homer_simpson', 2),
#  ('lisa_simpson', 'marge_simpson', 2),
#  ('maggie_simpson', 'bart_simpson', 2),
#  ('maggie_simpson', 'marge_simpson', 2),
#  ('maggie_simpson', 'ralph_wiggum', 2),
#  ('marge_simpson', 'bart_simpson', 2),
#  ('ralph_wiggum', 'bart_simpson', 2),
#  ('apu', 'bart_simpson', 1),
#  ('apu', 'lisa_simpson', 1),
#  ('apu', 'marge_simpson', 1),
#  ('homer_simpson', 'maggie_simpson', 1),
#  ('homer_simpson', 'ralph_wiggum', 1),
#  ('lisa_simpson', 'ralph_wiggum', 1),
#  ('maggie_simpson', 'apu', 1),
#  ('marge_simpson', 'lisa_simpson', 1),
#  ('marge_simpson', 'ralph_wiggum', 1),
#  ('ralph_wiggum', 'apu', 1),
#  ('ralph_wiggum', 'lisa_simpson', 1)]

# %% [markdown]
# Looking at the top losses we see again that there are some pictures in the wrong class or totally unrelated. In another cleaning phase we could further improve the performence by cleaning the dataset.

# %%
interp.plot_top_losses(16, figsize=(20,10))

# %% [markdown]
# In addition to the top losses on can also look at the minimum losses or in other words the images that were best classified:

# %%
interp.plot_top_losses(16, figsize=(20,10), largest=False)
